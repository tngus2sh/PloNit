# %%
# !pip install pymysql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pymysql

# %%
df = pd.read_excel('./행정동.xlsx')

# %%
df.drop(labels='말소일자', axis=1, inplace=True)
df.drop(labels='생성일자', axis=1, inplace=True)

df.head(10)
# Out:
#         행정동코드    시도명 시군구명   읍면동명
# 0  1100000000  서울특별시  NaN    NaN
# 1  1111000000  서울특별시  종로구    NaN
# 2  1111051500  서울특별시  종로구  청운효자동
# 3  1111053000  서울특별시  종로구    사직동
# 4  1111054000  서울특별시  종로구    삼청동
# 5  1111055000  서울특별시  종로구    부암동
# 6  1111056000  서울특별시  종로구    평창동
# 7  1111057000  서울특별시  종로구    무악동
# 8  1111058000  서울특별시  종로구    교남동
# 9  1111060000  서울특별시  종로구    가회동

# %%
dong = df.dropna(subset=['읍면동명'], axis=0)

dong
# Out:
#            행정동코드      시도명 시군구명   읍면동명
# 2     1111051500    서울특별시  종로구  청운효자동
# 3     1111053000    서울특별시  종로구    사직동
# 4     1111054000    서울특별시  종로구    삼청동
# 5     1111055000    서울특별시  종로구    부암동
# 6     1111056000    서울특별시  종로구    평창동
# ...          ...      ...  ...    ...
# 3882  5183031000  강원특별자치도  양양군     서면
# 3883  5183032000  강원특별자치도  양양군    손양면
# 3884  5183033000  강원특별자치도  양양군    현북면
# 3885  5183034000  강원특별자치도  양양군    현남면
# 3886  5183035000  강원특별자치도  양양군    강현면
#
# [3592 rows x 4 columns]

# %%
mydb = pymysql.connect(
    host='k9c207.p.ssafy.io',
    user='ssafy',
    password='ssafyc207',
    port=3306,
    db='plonit'
)

dbconn = mydb.cursor()
select_sql = 'SELECT gugun_id FROM gugun WHERE name = %s'
insert_sql = 'INSERT INTO dong (gugun_id, code, name) values (%s, %s, %s)'

result = []
for idx, row in dong.iterrows():
    dbconn = mydb.cursor()
    dbconn.execute(select_sql, (row['시군구명']))
    data = dbconn.fetchone()

    dbconn.execute(insert_sql, (data[0], row['행정동코드'], row['읍면동명']))

mydb.commit()
mydb.close()
