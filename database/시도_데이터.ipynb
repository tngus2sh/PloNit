# %%
# !pip install pymysql

# %%
import pandas as pd
import pymysql

# %%
df = pd.read_excel('./행정동.xlsx')

# %%
df.drop(labels='말소일자', axis=1, inplace=True)
df.drop(labels='생성일자', axis=1, inplace=True)

df.head(10)
# Out:
#         행정동코드    시도명 시군구명   읍면동명
# 0  1100000000  서울특별시  NaN    NaN
# 1  1111000000  서울특별시  종로구    NaN
# 2  1111051500  서울특별시  종로구  청운효자동
# 3  1111053000  서울특별시  종로구    사직동
# 4  1111054000  서울특별시  종로구    삼청동
# 5  1111055000  서울특별시  종로구    부암동
# 6  1111056000  서울특별시  종로구    평창동
# 7  1111057000  서울특별시  종로구    무악동
# 8  1111058000  서울특별시  종로구    교남동
# 9  1111060000  서울특별시  종로구    가회동

# %%
sido = df[df.시군구명.isna()]
sido = sido[sido.읍면동명.isna()]

sido
# Out:
#            행정동코드      시도명 시군구명 읍면동명
# 0     1100000000    서울특별시  NaN  NaN
# 452   2600000000    부산광역시  NaN  NaN
# 674   2700000000    대구광역시  NaN  NaN
# 836   2800000000    인천광역시  NaN  NaN
# 1009  2900000000    광주광역시  NaN  NaN
# 1112  3000000000    대전광역시  NaN  NaN
# 1200  3100000000    울산광역시  NaN  NaN
# 1262  3611000000  세종특별자치시  NaN  NaN
# 1288  4100000000      경기도  NaN  NaN
# 1289  4110500000    북부출장소  NaN  NaN
# 1917  4300000000     충청북도  NaN  NaN
# 2087  4400000000     충청남도  NaN  NaN
# 2315  4500000000     전라북도  NaN  NaN
# 2577  4600000000     전라남도  NaN  NaN
# 2924  4700000000     경상북도  NaN  NaN
# 3284  4800000000     경상남도  NaN  NaN
# 3621  5000000000  제주특별자치도  NaN  NaN
# 3667  5100000000  강원특별자치도  NaN  NaN
# 3668  5110500000    동해출장소  NaN  NaN

# %%
mydb = pymysql.connect(
    host='k9c207.p.ssafy.io',
    user='ssafy',
    password='ssafyc207',
    port=3306,
    db='plonit'
)

dbconn = mydb.cursor()

sql = 'INSERT INTO sido (code, name) values (%s, %s)'

for idx, row in sido.iterrows():
    print(row['행정동코드'], row['시도명'])
    dbconn.execute(sql, (row['행정동코드'], row['시도명']))

mydb.commit()
mydb.close()
# Out:
# 1100000000 서울특별시
# 2600000000 부산광역시
# 2700000000 대구광역시
# 2800000000 인천광역시
# 2900000000 광주광역시
# 3000000000 대전광역시
# 3100000000 울산광역시
# 3611000000 세종특별자치시
# 4100000000 경기도
# 4110500000 북부출장소
# 4300000000 충청북도
# 4400000000 충청남도
# 4500000000 전라북도
# 4600000000 전라남도
# 4700000000 경상북도
# 4800000000 경상남도
# 5000000000 제주특별자치도
# 5100000000 강원특별자치도
# 5110500000 동해출장소
