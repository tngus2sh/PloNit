# %%
# !pip install pymysql

# %%
import pandas as pd
import pymysql

# %%
df = pd.read_excel('./행정동.xlsx')

# %%
df.drop(labels='말소일자', axis=1, inplace=True)
df.drop(labels='생성일자', axis=1, inplace=True)

df.head(10)
# Out:
#         행정동코드    시도명 시군구명   읍면동명
# 0  1100000000  서울특별시  NaN    NaN
# 1  1111000000  서울특별시  종로구    NaN
# 2  1111051500  서울특별시  종로구  청운효자동
# 3  1111053000  서울특별시  종로구    사직동
# 4  1111054000  서울특별시  종로구    삼청동
# 5  1111055000  서울특별시  종로구    부암동
# 6  1111056000  서울특별시  종로구    평창동
# 7  1111057000  서울특별시  종로구    무악동
# 8  1111058000  서울특별시  종로구    교남동
# 9  1111060000  서울특별시  종로구    가회동

# %%
gugun = df[df.읍면동명.isna()]
gugun.dropna(subset=['시군구명'], axis=0, inplace=True)

gugun
# Out:
# <ipython-input-11-5b827730df64>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gugun.dropna(subset=['시군구명'], axis=0, inplace=True)
#            행정동코드      시도명 시군구명 읍면동명
# 1     1111000000    서울특별시  종로구  NaN
# 19    1114000000    서울특별시   중구  NaN
# 35    1117000000    서울특별시  용산구  NaN
# 52    1120000000    서울특별시  성동구  NaN
# 70    1121500000    서울특별시  광진구  NaN
# ...          ...      ...  ...  ...
# 3853  5179000000  강원특별자치도  화천군  NaN
# 3859  5180000000  강원특별자치도  양구군  NaN
# 3865  5181000000  강원특별자치도  인제군  NaN
# 3873  5182000000  강원특별자치도  고성군  NaN
# 3880  5183000000  강원특별자치도  양양군  NaN
#
# [276 rows x 4 columns]

# %%
mydb = pymysql.connect(
    host='k9c207.p.ssafy.io',
    user='ssafy',
    password='ssafyc207',
    port=3306,
    db='plonit'
)

dbconn = mydb.cursor()
select_sql = 'SELECT sido_id FROM sido WHERE name = %s'
insert_sql = 'INSERT INTO gugun (sido_id, code, name) values (%s, %s, %s)'

result = []
for idx, row in gugun.iterrows():
    dbconn = mydb.cursor()
    dbconn.execute(select_sql, (row['시도명']))
    data = dbconn.fetchone()

    dbconn.execute(insert_sql, (data[0], row['행정동코드'], row['시군구명']))

mydb.commit()
mydb.close()
